# %% [markdown]
# ## Avance de proyecto: Administración del uso de balones en Tecmilenio
#
# **Planteamiento** En la Universidad Tecmilenio, suele haber varios problemas cuando se piden balones para cualquier deporte, el primer problema es que
