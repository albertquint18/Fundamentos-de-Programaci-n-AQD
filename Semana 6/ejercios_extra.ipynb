# %% [markdown]
# ## Ejercicios Extras de Castigo

# %% [markdown]
# #### Ejercicio 1: Área de un triángulo
# Escribe un programa en Python que aplique el modelo Entrada-Proceso-Salida para calcular el área de un triángulo (`area = (base * altura) / 2`), usando `input()`, `float()` y `print()`.
# **Entrada:** `base = 8`, `altura = 5`
# **Salida:** `El área del triángulo es: 20.0`

# %%
base = int(input("Ingresa un número para la base"))
altura = float(input("Ingresa un valor para la altura"))
area = ((base * altura) / 2)
print(f"El area del triangulo es: {area}")
# Out:
# El area del triangulo es: 20.0

# %% [markdown]
# #### Ejercicio 2: Conversión de Celsius a Fahrenheit
# Escribe un programa en Python que pida una temperatura en grados Celsius y la convierta a Fahrenheit (`F = C * 9/5 + 32`).
# **Entrada:** `celsius = 30`
# **Salida:** `30 grados Celsius equivalen a 86.0 grados Fahrenheit`

# %%
temp = float(input("Ingresa una temperatura en grados celsius: "))
far = temp * 9/5 + 32
print(f"{temp} grados Celsius equivalen a {far} grados Fahrenheit")
# Out:
# 30.0 grados Celsius equivalen a 86.0 grados Fahrenheit

# %% [markdown]
# #### Ejercicio 3: Interés simple (antes en PSeInt)
# Escribe un programa en Python que pida capital, tasa y tiempo, y calcule el interés simple (`interes = capital * (tasa / 100) * tiempo`).
# **Entrada:** `capital = 2000`, `tasa = 6`, `tiempo = 2`
# **Salida:** `El interés simple es: 240.0`

# %%
cap = int(input("Ingresa el capital: "))
tas = int(input("Ingresa la tasa: "))
tiemp = int(input("Ingresa el tiempo: "))
interes = cap * (tas / 100) * tiemp
print(f"El interés simple es: {interes}")
# Out:
# El interés simple es: 240.0

# %% [markdown]
# #### Ejercicio 4: Precedencia de operadores (antes de análisis teórico)
# Escribe un programa en Python que calcule `4 * 3 + 10 // 3 - 8 % 5`, muestre el resultado y **imprima el orden de evaluación aplicado** (`12 + 3 - 3`).
# **Salida:**
# ```
# 4 * 3 + 10 // 3 - 8 % 5 = 12 + 3 - 3 = 12
# ```

# %%
res = 4 * 3 + 10 // 3 - 8 % 5 
print(f"4 * 3 + 10 // 3 - 8 % 5 = 12 + 3 - 3 = 12: {res}")
# Out:
# 4 * 3 + 10 // 3 - 8 % 5 = 12 + 3 - 3 = 12: 12

# %% [markdown]
# #### Ejercicio 5: Casting tras `input()` (antes de análisis teórico)
# Escribe un programa en Python que pida un número con `input()`, demuestre que devuelve `str` (`type()`), intente `x + 1` dentro de `try-except` capturando `TypeError`, y finalmente haga `int(x)` para sumar y obtener el resultado correcto.
# **Entrada:** `"25"`
# **Salida:** `x es tipo str`, `x + 1 genera TypeError`, `int(x) + 1 = 26`

# %%
x = input("Elige un número: ")
if type(x) == str:
    print("x es str")
try:
    resi = x + 1
except TypeError:
    print("x + 1 es TypeError")
x = int(x)
resi = x + 1
print(f"int(x) + 1 = {resi} ")
# Out:
# x es str
# x + 1 es TypeError
# int(x) + 1 = 26

# %% [markdown]
# #### Ejercicio 6: Conversión de horas a segundos
# Crea un programa que pida una cantidad de horas (`float`) y la convierta a segundos (1 hora = 3600 segundos), mostrando el resultado formateado.
# **Entrada:** `3`
# **Salida:** `3 horas equivalen a 10800 segundos`

# %%
hr = float(input("Ingresa una hora: "))
hr = int(hr)
segs = hr * 3600
segs = int(segs)
print(f"{hr} horas equivalen a {segs} segundos")
# Out:
# 3 horas equivalen a 10800 segundos

# %% [markdown]
# #### Ejercicio 7: Descuento del 15% con f-strings
# Crea un programa que pida el precio de un artículo y aplique un 15% de descuento, mostrando el monto del descuento y el precio final con dos decimales usando f-strings.
# **Entrada:** `460`
# **Salida:**
# ```
# Descuento (15%): $69.00
# Precio final: $391.00
# ```

# %%
art = float(input("Ingresa el costo del artículo: "))
do = art * 0.15
des = art * 0.85
print(f"Descuento (15%): ${do: .2f}\nPrecio final: ${des: .2f}")
# Out:
# Descuento (15%): $ 69.00
# Precio final: $ 391.00

# %% [markdown]
# #### Ejercicio 8: Número par o impar
# **Entrada:** `17` → **Salida:** `17 es un número impar`

# %%
nume = int(input("Ingresa un número entero: "))
if nume % 2 == 0:
    print(f"{nume} es un número par")
else:
    print(f"{nume} es un número impar")
# Out:
# 17 es un número impar

# %% [markdown]
# #### Ejercicio 9: Mayor de tres números
# **Entrada:** `12`, `45`, `23` → **Salida:** `El mayor de los tres números es: 45`

# %%
a = int(input("Ingresa un número entero: "))
b = int(input("Ingresa otro número entero: "))
c = int(input("Ingresa un ultimo número entero: "))
if a > b and a > c:
    print(f"{a} es el mayor")
elif b > a and b > c:
    print(f"{b} es el mayor")
else:
    print(f"{c} es el mayor")
# Out:
# 45 es el mayor

# %% [markdown]
# #### Ejercicio 10: Suma acumulada con `while`
# Pide números mientras sean distintos de `0` (el `0` termina el ciclo y no se suma).
# **Entrada:** `5`, `8`, `2`, `0` → **Salida:** `La suma de los números es: 15`

# %%
su = 0
nome = int(input("introduce un número: "))
while nome != 0:
    su += nome
    nome = int(input("introduce un número: "))
print(f"La suma de los números es: {su}")
# Out:
# La suma de los números es: 15

# %% [markdown]
# #### Ejercicio 11: Tabla de multiplicar con `for`
# **Entrada:** `6` → **Salida:** tabla del 6 del `6 x 1 = 6` al `6 x 10 = 60`

# %%
tab = int(input("Qué tabla quieres: "))
for i in range(1, 11):
    mul = tab * i
    print(f"{tab}x{i}= {mul}")
# Out:
# 6x1= 6
# 6x2= 12
# 6x3= 18
# 6x4= 24
# 6x5= 30
# 6x6= 36
# 6x7= 42
# 6x8= 48
# 6x9= 54
# 6x10= 60

# %% [markdown]
# #### Ejercicio 12: Suma de pares del 1 al 20 con `for` y `continue`
# **Salida:** `La suma de los números pares del 1 al 20 es: 110`

# %%
suma = 0
for i in range(1, 21):
    if i % 2 != 0:
        continue
    suma += i
print(f"La suma de los números pares del 1 añ 20 es: {suma}")
# Out:
# La suma de los números pares del 1 añ 20 es: 110

# %% [markdown]
# #### Ejercicio 13: Suma de una lista con función que regresa valor (sin `sum()`)
# **Entrada:** `[10, 20, 30, 40]` → **Salida:** `La suma de los elementos es: 100`

# %%
def sonm(lisst):
    total = 0
    for nowe in lisst:
        total += nowe
    return total
nums = [10, 20, 30, 40]
re = sonm(nums)
print(re)
# Out:
# 100

# %% [markdown]
# #### Ejercicio 14: Máximo de una lista con función que regresa valor (sin `max()`)
# **Entrada:** `[7, 3, 9, 2]` → **Salida:** `El elemento máximo es: 9`

# %%
def maxx(lista):
    oldi = lista[0]
    for nome in lista:
        if nome > oldi:
            oldi = nome
    return oldi
nomes = [7, 3, 9, 2]
re = maxx(nomes)
print(re)
# Out:
# 9

# %% [markdown]
# #### Ejercicio 15: Matriz y suma de la diagonal principal
# **Entrada:** `[[1,2,3],[4,5,6],[7,8,9]]` → **Salida:** `La suma de la diagonal principal es: 15`

# %%
elpepe = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
con = 0
for i in range(len(elpepe)):
    con += elpepe[i][i]

print(f"La suma de la diagonal principal es: {con}")
# Out:
# La suma de la diagonal principal es: 15

# %% [markdown]
# #### Ejercicio 16: Promedio con función que no regresa valor
# **Entrada:** `[8, 9, 10, 7]` → **Salida:** `El promedio es: 8.50`

# %%
def promedio(numi):
    suma = sum(numi)
    re = suma / len(numi)
    print(f"El promedio es: {re:.2f}")
numi = [8, 9, 10, 7]
promedio(numi)
# Out:
# El promedio es: 8.50

# %% [markdown]
# #### Ejercicio 17: Invertir una lista con slicing
# **Entrada:** `[1, 2, 3, 4, 5]` → **Salida:** `Lista invertida: [5, 4, 3, 2, 1]`

# %%
lista = [1, 2, 3, 4, 5]
lreve = lista[::-1]
print("Lista invertida:", lreve)
# Out:
# Lista invertida: [5, 4, 3, 2, 1]

# %% [markdown]
# #### Ejercicio 18: Factorial con función recursiva
# **Entrada:** `5` → **Salida:** `El factorial de 5 es: 120`

# %%
def factos(l):
    if l == 1:
        return 1
    else:
        return l * factos(l - 1)
nume = int(input("Ingresa un número: "))
resultado = factos(nume)
print(f"El factorial de {nume}, es {resultado}")
# Out:
# El factorial de 5, es 120

# %% [markdown]
# #### Ejercicio 19: Tupla: acceso y suma con función
# **Entrada:** `(4, 8, 15, 16, 23, 42)` → **Salida:**
# ```
# El tercer elemento es: 15
# La suma de la tupla es: 108
# ```

# %%
def suma_tu(tupla):
    return sum(tupla)
tup = (4, 8, 15, 16, 23, 42)
print("el tercer elemento es:", tup[2])
re = suma_tu(tup)
print("La suma de la tupla es:", re)
# Out:
# el tercer elemento es: 15
# La suma de la tupla es: 108

# %% [markdown]
# #### Ejercicio 20: Diccionario: buscar teléfono de un contacto
# **Entrada:** `Beto` → **Salida:** `El teléfono de Beto es: 5555678`

# %%
contactos = {
    "Beto": "5555678",
    "Fred": "5555876"
}
def buscar_phon():
    nom = input("Ingresa el contacto a buscar: ")
    if nom in contactos:
        print(f"El telefono de {nom} es {contactos[nom]}")
    else:
        print("Ese bro no esta aquí")
buscar_phon()
# Out:
# El telefono de Beto es 5555678

# %% [markdown]
# #### Ejercicio 21: Diccionario de calificaciones y promedios
# **Entrada:** `{"Ana": [8, 9, 10], "Beto": [7, 7, 8]}` → **Salida:**
# ```
# Ana: 9.00
# Beto: 7.33
# ```

# %%
calif = {
    "Ana": [8, 9, 10],
    "Beto": [7, 7, 8]
}
for nombre, notas in calif.items():
    prom = sum(notas) / len(notas)
    print(f"{nombre}: {prom:.2f}")
# Out:
# Ana: 9.00
# Beto: 7.33

# %% [markdown]
# #### Ejercicio 22: Excepción de división entre cero
# **Entrada:** `10`, `0` → **Salida:** `Error: No se puede dividir entre cero.`

# %%
try: 
    nom1 = int(input("Introduce un número: "))
    nom2 = int(input("Ahora por el que se divide: "))
    divi = nom1 / nom2
    print(f"la divición es: {divi}")
except ZeroDivisionError:
    print("No se puede dividir entre cero")
# Out:
# No se puede dividir entre cero

# %% [markdown]
# #### Ejercicio 23: Excepción de valor no numérico
# **Entrada:** `"abc"` → **Salida:** `Error: Debes ingresar un número entero.`

# %%
try:
    nom = int(input("Introduce un número entero: "))
    print("Número ingresado:", nom)
except ValueError:
    print("Error: Debes ingresar un número entero.")
# Out:
# Error: Debes ingresar un número entero.

# %% [markdown]
# #### Ejercicio 24: Contar palabras de un string
# **Entrada:** `"Python es un lenguaje de programacion"` → **Salida:** `El mensaje tiene 6 palabras.`

# %%
pal = input("Pon un mensaje con python: ")
nome = pal.split()
print(f"El mensaje tine {len(nome)} palabras")
# Out:
# El mensaje tine 6 palabras

# %% [markdown]
# #### Ejercicio 25: Longitud, mayúsculas y reemplazo de un string
# **Entrada:** `"aprende python"` → **Salida:**
# ```

# %%
mens = input("Esribe un mensaje con python: ")
print(f"longitud: {len(mens)}")
print(f"Mayuscula: {mens.upper()}")
print(f"Remplazo con Java: {mens.replace("python", "java")}")
# Out:
# longitud: 14
# Mayuscula: APRENDE PYTHON
# Remplazo con Java: aprende java
