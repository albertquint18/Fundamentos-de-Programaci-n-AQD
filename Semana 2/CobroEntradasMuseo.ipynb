# %% [markdown]
# # Actividad Evaluable semana 2: Costos y descuentos de un museo
# --Alberto Quintanar Dominguez.
# --Matricula = 03087401
#
# Se desarrollo un programa en **python** para poder cobrar las entradas de los visitantes del **Museo de Antropología e Historia** calculando el precio adecuado para cada visitante y aplicando descuentos por tipo de visitante bajo estrictas condiciones logicas. Esto se logro gracias a ciclos controlados que dieron valores a la tabla final.

# %%
personas = int(input("Bienvenido al museo de A.H. ¿Cuántas personas son?:"))
for i in range(1, personas + 1):
    edad = int(input(f"Ingresa edad de la persona {i}: "))
    costo = 45 or 30 or 0
    if edad >= 18:
        costo = 45
    elif edad >= 3:
        costo = 30
    else:
        costo = 0

    tipo = input(f"Ingresa el tipo de boleto (Adulto mayor = 4, Estudiante = 5, profesor = 6, otro = 7) para la persona {i}: ")
    while tipo == "4" and edad < 60:
        print("invalido")
        tipo = input(f"Ingresa el tipo de boleto (Adulto mayor = 4, Estudiante = 5, profesor = 6, otro = 7)")
        if tipo == "4" and edad >= 60:
                break
    descuento = 10 or 12 or 0
    if tipo == "4":
        descuento = 12
    elif tipo == "5" or tipo == "6":
        descuento = 10
    else:
        descuento = 0
    if tipo == "4" and edad >= 60:
         precio_final = costo * 0.88
    elif tipo == "5" and edad < 18:
        precio_final = costo * 0.90
    elif tipo == "6" and edad >=18 or (tipo == "5" and edad >= 18):
        precio_final = costo * 0.90
    elif tipo == "7" and edad >= 18:
        precio_final = costo
    elif tipo == "7" and edad >= 3:
        precio_final = costo
    else:
        precio_final = costo
    print("Tabla de datos")

    print("Persona\tPrecio\tDescuento\tPrecio fianl")
    print(f" {i}\t${costo}\t %{descuento}\t          ${precio_final}")
# Out:
# Tabla de datos
# Persona	Precio	Descuento	Precio fianl
#  1	$30	 %10	          $27.0
# Tabla de datos
# Persona	Precio	Descuento	Precio fianl
#  2	$0	 %0	          $0
# invalido
# invalido
# invalido
# invalido
# invalido
# invalido
# Tabla de datos
# Persona	Precio	Descuento	Precio fianl
#  3	$45	 %10	          $40.5
# Tabla de datos
# Persona	Precio	Descuento	Precio fianl
#  4	$45	 %12	          $39.6
# Tabla de datos
# Persona	Precio	Descuento	Precio fianl
#  5	$45	 %10	          $40.5
